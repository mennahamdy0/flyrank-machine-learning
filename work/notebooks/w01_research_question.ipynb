# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mennahamdy0/flyrank-machine-learning/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# ### My Lane
#
# I chose **Refresh / Content Opportunity Scoring** because it focuses on identifying which pages should be reviewed or refreshed first. Content teams often manage many pages, so prioritizing them can save time and effort. I want to explore how search performance signals can be used to rank pages that may benefit from updates and provide decision-support recommendations.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# ### Research Question
#
# My goal is to identify which pages should be refreshed first based on their search performance signals.
#
# **Decision:** Which pages should be prioritized for content refresh.
#
# **Who takes the action:** The content or SEO team.
#
# **Action:** Review and update the highest-priority pages first.
#
# **Cost of a wrong recommendation:** Recommending the wrong pages may waste time and resources, while missing important pages could delay potential improvements in search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# ### Quick Look at the Data
#
# From the starter dataset:
#
# - The correlation between `search_volume` and `impressions_90d` (after filtering pages with impressions > 0) was **0.001**, showing a very weak linear relationship.
# - Increasing the Decision Tree depth from **2** to **3** improved **Precision@50** from **0.60** to **0.72**.
#
# These observations suggest that simple assumptions may not be enough, and combining multiple signals could produce better recommendations.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# ### Careful Words
#
# This project aims to provide decision-support based on observed patterns in the available dataset.
#
# The results may indicate useful relationships between search signals and content performance, but they do not prove causation or predict Google's ranking algorithm.
#
# Any recommendations will be treated as evidence-based suggestions, not guaranteed outcomes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
